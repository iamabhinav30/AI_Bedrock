# %%
import sys, os
sys.path.append(os.path.dirname(os.path.abspath("__file__")))

from bedrock_client import client, model_id
from bedrock_helpers import add_user_message, add_assistant_message, chat

# %%
# Control output with temperature (0.0 = deterministic, 1.0 = creative)
messages = []
add_user_message(messages, 'Is coffee or tea better for breakfast?')
add_assistant_message(messages, 'Tea is better because')


chat(messages, temperature=1.0)
# Out:
# " it has more flavonoids and antioxidants than coffee, and less caffeine, which makes it gentler on the stomach. Tea also has a more gradual energy release rather than the quick spike and crash that can come with coffee.\n\nBut honestly, both coffee and tea can be good breakfast options - it really depends on your personal preferences, caffeine tolerance, and how your body responds to each. Some people need that stronger caffeine kick from coffee to start their day, while others prefer tea's milder effect. \n\nWhat matters most is choosing whichever you enjoy and that makes you feel good in the morning!"

# %%
messages = []

add_user_message(messages, "Count from 1 to 10")

chat(messages, temperature=0.0, stop_sequences=['5'])
# Out:
# '1, 2, 3, 4, '
