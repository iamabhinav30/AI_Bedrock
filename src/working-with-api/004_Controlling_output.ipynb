# %%
import sys, os
sys.path.append(os.path.join(os.path.dirname(os.path.abspath("__file__")), ".."))

from bedrock_client import client, model_id_sonnet4
from bedrock_helpers import add_user_message, add_assistant_message, chat_sonnet4

# %%
# Control output with temperature (0.0 = deterministic, 1.0 = creative)
messages = []
add_user_message(messages, 'Is coffee or tea better for breakfast?')
add_assistant_message(messages, 'Tea is better because')


chat_sonnet4(messages, temperature=1.0)
# Out:
# ' it hydrates better than coffee, has lower amounts of caffeine to avoid jitters, and also has antioxidants that can benefit your health.\n\nHowever, both are great breakfast drinks and it really depends on your own personal preferences!\n\nSome points to consider:\n\n**Tea advantages:**\n- Generally less acidic, easier on an empty stomach\n- More hydrating\n- L-theanine can provide calm, focused energy\n- Wide variety of flavors and types\n\n**Coffee advantages:**  \n- Higher caffeine content for those who need a stronger energy boost\n- May boost metabolism slightly\n- Rich, bold flavor many people crave in the morning\n- Pairs well with many breakfast foods\n\nThe "better" choice really comes down to your caffeine tolerance, taste preferences, and how your body responds to each. What matters most is choosing something you enjoy that helps start your day well!'

# %%
messages = []

add_user_message(messages, "Count from 1 to 10")

chat_sonnet4(messages, temperature=0.0, stop_sequences=['5'])
# Out:
# '1, 2, 3, 4, '

# %%
messages = []

add_user_message(messages, 'generate a very short event bridge rule as json')
add_assistant_message(messages, "```json")
text = chat_sonnet4(messages, stop_sequences=["```"], temperature=0.0)

text
# Out:
# '\n{\n  "Name": "OrderProcessingRule",\n  "EventPattern": {\n    "source": ["myapp.orders"],\n    "detail-type": ["Order Placed"]\n  },\n  "Targets": [\n    {\n      "Id": "1",\n      "Arn": "arn:aws:lambda:us-east-1:123456789012:function:ProcessOrder"\n    }\n  ]\n}\n'

# %%
import json
json.loads(text)
# Out:
# {'Name': 'OrderProcessingRule',
#  'EventPattern': {'source': ['myapp.orders'], 'detail-type': ['Order Placed']},
#  'Targets': [{'Id': '1',
#    'Arn': 'arn:aws:lambda:us-east-1:123456789012:function:ProcessOrder'}]}

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short.
"""

add_user_message(messages, prompt)

text = chat_sonnet4(messages)
text.strip()

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short.
"""

add_user_message(messages, prompt)

text = chat_sonnet4(messages)
text.strip()

# %%
messages = []

prompt = """
Generate three different sample AWS CLI commands. Each should be very short.
"""

add_user_message(messages, prompt)
add_assistant_message(messages, "```bash")

text = chat_sonnet4(messages)
text.strip()
# Out:
# 'aws s3 ls\n\naws ec2 describe-instances\n\naws iam list-users\n```'

# %%
from IPython.display import display, Markdown

Markdown(text)
